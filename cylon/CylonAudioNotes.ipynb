# %% [markdown]
# ### LibRosa
# [Pitch-Shift Notebook(important!)](https://github.com/JentGent/pitch-shift)
# [librosa.decompose.decompose](https://librosa.org/doc/latest/generated/librosa.decompose.decompose.html)
# [key to notes](https://librosa.org/doc/main/generated/librosa.key_to_notes.html)
# [note to hz](https://librosa.org/doc/latest/generated/librosa.note_to_hz.html)
#
#
# ### Phase Vocoder / Autotune / Audacity
# [The Science Behind Auto-Tune: How It Works](https://www.antarestech.com/community/the-science-behind-auto-tune)
# [ChannelVocoder](https://github.com/ederwander/ChannelVocoder/blob/main/EderwanderVocoderOnTheFly.py)
# [Audacity Vocoder](https://manual.audacityteam.org/man/vocoder.html)
# [PyAudacity: A Python module to control a running instance of Audacity through its mod-script-pipe macro system.](https://github.com/asweigart/pyaudacity)
# [Audacity Scripting](https://manual.audacityteam.org/man/scripting.html)
# [Pitch Correction with Logic](https://www.soundonsound.com/techniques/pitch-correction-logic)
# [logic pro set project tempo](https://logicpro.skydocu.com/en/work-with-projects/set-project-properties/set-the-project-tempo/)
# [Building a noise vocoder with Python](https://github.com/achabotl/vocoder/blob/master/Vocoder.ipynb)
#
#
# ### other logic pro
# [Use Quick Sampler to edit and play single samples in Logic Pro for Mac](https://support.apple.com/en-us/102041)
# [Channel strip controls in Logic Pro](https://support.apple.com/guide/logicpro/channel-strip-controls-lgcpbc219210/10.6.2/mac/10.15.7)
#
#
# ### Physics
# [Fast Fourier Transforms With Python](https://notebook.community/mholtrop/Phys605/Python/FFT/FFT+example1)
# [How do I measure the frequency of a singing voice?](https://www.quora.com/How-do-I-measure-the-frequency-of-a-singing-voice)
#
# ### Commodore / SID
# [Sid/Commodore 64 style sounds?](https://www.logicprohelp.com/forums/topic/15424-sidcommodore-64-style-sounds/)
#
# ### Music
# [C musical note WP](https://en.wikipedia.org/wiki/C_(musical_note))
# [A440 pitch standard WP](https://en.wikipedia.org/wiki/A440_(pitch_standard))
# [Equal Temperament WP](https://en.wikipedia.org/wiki/Equal_temperament)
# [Piano Key Frequencies WP](https://en.wikipedia.org/wiki/Piano_key_frequencies)
# [List of musical symbols WP](https://en.wikipedia.org/wiki/List_of_musical_symbols)
# [Musical Staff WP](https://en.wikipedia.org/wiki/Staff_(music))
# [Key Signature WP](https://en.wikipedia.org/wiki/Key_signature)
# [Shorthand for orchestra instrumentation WP](https://en.wikipedia.org/wiki/Shorthand_for_orchestra_instrumentation)
# [Tritone WP](https://en.wikipedia.org/wiki/Tritone)
# [Circle of Fifths WP](https://en.wikipedia.org/wiki/Circle_of_fifths)
# [Musical Key WP](https://en.wikipedia.org/wiki/Key_(music))
# [clef diagram wp](https://en.wikipedia.org/wiki/Clef#/media/File:Clef_Diagram.png)
# [musical chord wp](https://en.wikipedia.org/wiki/Chord_(music))
# [major and minor wp](https://en.wikipedia.org/wiki/Major_and_minor)
# [perfect fifth wp](https://en.wikipedia.org/wiki/Perfect_fifth)
#
#
# [The tritone: the devil's interval and how to use it](https://splice.com/blog/tritone-the-devils-interval/)
# [Music, Piano keyboard, Octave, Pitch class, Major diatonic scale, Major chord, Chromatic scale, Tempered scale, Staff, Clef.](https://solitaryroad.com/c1060.html)

# %% [markdown]
# [Piano Key Frequencies Chart](https://upload.wikimedia.org/wikipedia/commons/thumb/a/ad/Piano_key_frequencies.png/800px-Piano_key_frequencies.png)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Clef Diagram
#
# ![image.png](attachment:image.png)
